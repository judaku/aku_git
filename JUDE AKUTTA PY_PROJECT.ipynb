# %% [markdown]
# ## NAME : JUDE AKUTTA
# ## COURSE : DATA  ANALYSIS
# ## TASK : PYTHON PROJECT

# %%
import pandas as pd

# %%
# Loading the dataset from its storage path) 

globe = pd.read_csv('./sand/global_food_prices.csv.zip')      
globe
# Out:
# C:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          adm0_id    adm0_name  adm1_id   adm1_name  mkt_id    mkt_name  cm_id  \
# 0            1.0  Afghanistan      272  Badakhshan     266    Fayzabad     55
# 1            1.0  Afghanistan      272  Badakhshan     266    Fayzabad     55
# 2            1.0  Afghanistan      272  Badakhshan     266    Fayzabad     55
# 3            1.0  Afghanistan      272  Badakhshan     266    Fayzabad     55
# 4            1.0  Afghanistan      272  Badakhshan     266    Fayzabad     55
# ...          ...          ...      ...         ...     ...         ...    ...
# 2050633    271.0     Zimbabwe     3444    Midlands    5594  Mbilashaba    432
# 2050634    271.0     Zimbabwe     3444    Midlands    5594  Mbilashaba    539
# ...

# %%
globe.shape
# Out:
# (2050638, 18)

# %%
 # clearing the error
    
globe = pd.read_csv('./sand/global_food_prices.csv.zip',low_memory=False)   
globe
# Out:
#          adm0_id    adm0_name  adm1_id   adm1_name  mkt_id    mkt_name  cm_id  \
# 0            1.0  Afghanistan      272  Badakhshan     266    Fayzabad     55
# 1            1.0  Afghanistan      272  Badakhshan     266    Fayzabad     55
# 2            1.0  Afghanistan      272  Badakhshan     266    Fayzabad     55
# 3            1.0  Afghanistan      272  Badakhshan     266    Fayzabad     55
# 4            1.0  Afghanistan      272  Badakhshan     266    Fayzabad     55
# ...          ...          ...      ...         ...     ...         ...    ...
# 2050633    271.0     Zimbabwe     3444    Midlands    5594  Mbilashaba    432
# 2050634    271.0     Zimbabwe     3444    Midlands    5594  Mbilashaba    539
# 2050635    271.0     Zimbabwe     3444    Midlands    5594  Mbilashaba    540
# 2050636    271.0     Zimbabwe     3444    Midlands    5594  Mbilashaba    541
# 2050637    271.0     Zimbabwe     3444    Midlands    5594  Mbilashaba    887
#
# ...

# %%
# Deleting the last column without values

globe1=globe.drop(globe.columns[-1],axis=1)
globe1
# Out:
#          adm0_id    adm0_name  adm1_id   adm1_name  mkt_id    mkt_name  cm_id  \
# 0            1.0  Afghanistan      272  Badakhshan     266    Fayzabad     55
# 1            1.0  Afghanistan      272  Badakhshan     266    Fayzabad     55
# 2            1.0  Afghanistan      272  Badakhshan     266    Fayzabad     55
# 3            1.0  Afghanistan      272  Badakhshan     266    Fayzabad     55
# 4            1.0  Afghanistan      272  Badakhshan     266    Fayzabad     55
# ...          ...          ...      ...         ...     ...         ...    ...
# 2050633    271.0     Zimbabwe     3444    Midlands    5594  Mbilashaba    432
# 2050634    271.0     Zimbabwe     3444    Midlands    5594  Mbilashaba    539
# 2050635    271.0     Zimbabwe     3444    Midlands    5594  Mbilashaba    540
# 2050636    271.0     Zimbabwe     3444    Midlands    5594  Mbilashaba    541
# 2050637    271.0     Zimbabwe     3444    Midlands    5594  Mbilashaba    887
#
# ...

# %%
# Renaming the columns for readability

globe1.columns=['Country_ID','Country_Name','Locality_ID',
               'Locality','Market_ID','Market_Name',
               'Commodity_ID','Commodity_Name','Currency_ID',
               'Currency_Name','MarketType_ID','MarketType',
               'UnitOfMeas_ID','UnitsOfMeas','Month','Year','Price']
globe1
# Out:
#          Country_ID Country_Name  Locality_ID    Locality  Market_ID  \
# 0               1.0  Afghanistan          272  Badakhshan        266
# 1               1.0  Afghanistan          272  Badakhshan        266
# 2               1.0  Afghanistan          272  Badakhshan        266
# 3               1.0  Afghanistan          272  Badakhshan        266
# 4               1.0  Afghanistan          272  Badakhshan        266
# ...             ...          ...          ...         ...        ...
# 2050633       271.0     Zimbabwe         3444    Midlands       5594
# 2050634       271.0     Zimbabwe         3444    Midlands       5594
# 2050635       271.0     Zimbabwe         3444    Midlands       5594
# 2050636       271.0     Zimbabwe         3444    Midlands       5594
# 2050637       271.0     Zimbabwe         3444    Midlands       5594
#
#         Market_Name  Commodity_ID           Commodity_Name  Currency_ID  \
# ...

# %%
# Deleting these measurement and currency id  columns since no clear-cut specification

globe2=globe1.drop(['UnitOfMeas_ID','UnitsOfMeas','Currency_ID','MarketType_ID'],axis=1)
globe2
# Out:
#          Country_ID Country_Name  Locality_ID    Locality  Market_ID  \
# 0               1.0  Afghanistan          272  Badakhshan        266
# 1               1.0  Afghanistan          272  Badakhshan        266
# 2               1.0  Afghanistan          272  Badakhshan        266
# 3               1.0  Afghanistan          272  Badakhshan        266
# 4               1.0  Afghanistan          272  Badakhshan        266
# ...             ...          ...          ...         ...        ...
# 2050633       271.0     Zimbabwe         3444    Midlands       5594
# 2050634       271.0     Zimbabwe         3444    Midlands       5594
# 2050635       271.0     Zimbabwe         3444    Midlands       5594
# 2050636       271.0     Zimbabwe         3444    Midlands       5594
# 2050637       271.0     Zimbabwe         3444    Midlands       5594
#
#         Market_Name  Commodity_ID           Commodity_Name Currency_Name  \
# ...

# %%
# To view duplicates the month column must leave since most vales associated with it are repeated

globe3=globe2.drop('Month',axis=1)
globe3
# Out:
#          Country_ID Country_Name  Locality_ID    Locality  Market_ID  \
# 0               1.0  Afghanistan          272  Badakhshan        266
# 1               1.0  Afghanistan          272  Badakhshan        266
# 2               1.0  Afghanistan          272  Badakhshan        266
# 3               1.0  Afghanistan          272  Badakhshan        266
# 4               1.0  Afghanistan          272  Badakhshan        266
# ...             ...          ...          ...         ...        ...
# 2050633       271.0     Zimbabwe         3444    Midlands       5594
# 2050634       271.0     Zimbabwe         3444    Midlands       5594
# 2050635       271.0     Zimbabwe         3444    Midlands       5594
# 2050636       271.0     Zimbabwe         3444    Midlands       5594
# 2050637       271.0     Zimbabwe         3444    Midlands       5594
#
#         Market_Name  Commodity_ID           Commodity_Name Currency_Name  \
# ...

# %%
# Show where duplicates are found

globe3.duplicated()
# Out:
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 2050633    False
# 2050634    False
# 2050635    False
# 2050636    False
# 2050637    False
# Length: 2050638, dtype: bool

# %%
# View duplicates

globe3[globe3.duplicated()]
# Out:
#          Country_ID Country_Name  Locality_ID    Locality  Market_ID  \
# 1               1.0  Afghanistan          272  Badakhshan        266
# 2               1.0  Afghanistan          272  Badakhshan        266
# 3               1.0  Afghanistan          272  Badakhshan        266
# 4               1.0  Afghanistan          272  Badakhshan        266
# 5               1.0  Afghanistan          272  Badakhshan        266
# ...             ...          ...          ...         ...        ...
# 2050454       271.0     Zimbabwe         3444    Midlands       5509
# 2050523       271.0     Zimbabwe         3444    Midlands       5544
# 2050590       271.0     Zimbabwe         3444    Midlands       5585
# 2050599       271.0     Zimbabwe         3444    Midlands       5585
# 2050604       271.0     Zimbabwe         3444    Midlands       5585
#
#         Market_Name  Commodity_ID            Commodity_Name Currency_Name  \
# ...

# %%
# Delete duplicates

globe4=globe3.drop_duplicates()
globe4
# Out:
#          Country_ID Country_Name  Locality_ID    Locality  Market_ID  \
# 0               1.0  Afghanistan          272  Badakhshan        266
# 12              1.0  Afghanistan          272  Badakhshan        266
# 19              1.0  Afghanistan          272  Badakhshan        266
# 20              1.0  Afghanistan          272  Badakhshan        266
# 21              1.0  Afghanistan          272  Badakhshan        266
# ...             ...          ...          ...         ...        ...
# 2050633       271.0     Zimbabwe         3444    Midlands       5594
# 2050634       271.0     Zimbabwe         3444    Midlands       5594
# 2050635       271.0     Zimbabwe         3444    Midlands       5594
# 2050636       271.0     Zimbabwe         3444    Midlands       5594
# 2050637       271.0     Zimbabwe         3444    Midlands       5594
#
#         Market_Name  Commodity_ID           Commodity_Name Currency_Name  \
# ...

# %%
# Since it's about food,therefore the non-food commodity should be selected and removed

mask=globe4['Commodity_ID']==274
globe4[mask]                                # Labour wage
# Out:
#          Country_ID Country_Name  Locality_ID    Locality  Market_ID  \
# 435             1.0  Afghanistan          272  Badakhshan        266
# 436             1.0  Afghanistan          272  Badakhshan        266
# 441             1.0  Afghanistan          272  Badakhshan        266
# 442             1.0  Afghanistan          272  Badakhshan        266
# 444             1.0  Afghanistan          272  Badakhshan        266
# ...             ...          ...          ...         ...        ...
# 1996381       269.0        Yemen       144971      Raymah       1947
# 1996384       269.0        Yemen       144971      Raymah       1947
# 1996385       269.0        Yemen       144971      Raymah       1947
# 1996392       269.0        Yemen       144971      Raymah       1947
# 1996404       269.0        Yemen       144971      Raymah       1947
#
#         Market_Name  Commodity_ID                    Commodity_Name  \
# 435        Fayzabad           274  Wage (qualified labour) - Retail
# ...

# %%
mask=globe4['Commodity_ID']==284
globe4[mask]                               # Fuel(diesel)
# Out:
#          Country_ID Country_Name  Locality_ID    Locality  Market_ID  \
# 537             1.0  Afghanistan          272  Badakhshan        266
# 538             1.0  Afghanistan          272  Badakhshan        266
# 539             1.0  Afghanistan          272  Badakhshan        266
# 540             1.0  Afghanistan          272  Badakhshan        266
# 541             1.0  Afghanistan          272  Badakhshan        266
# ...             ...          ...          ...         ...        ...
# 1996524       269.0        Yemen       144971      Raymah       1947
# 1996525       269.0        Yemen       144971      Raymah       1947
# 1996526       269.0        Yemen       144971      Raymah       1947
# 1996527       269.0        Yemen       144971      Raymah       1947
# 1996528       269.0        Yemen       144971      Raymah       1947
#
#         Market_Name  Commodity_ID          Commodity_Name Currency_Name  \
# ...

# %%
mask=globe4['Commodity_ID']==305
globe4[mask]                                         # Exchange rate
# Out:
#          Country_ID Country_Name  Locality_ID    Locality  Market_ID  \
# 665             1.0  Afghanistan          272  Badakhshan        266
# 666             1.0  Afghanistan          272  Badakhshan        266
# 667             1.0  Afghanistan          272  Badakhshan        266
# 668             1.0  Afghanistan          272  Badakhshan        266
# 669             1.0  Afghanistan          272  Badakhshan        266
# ...             ...          ...          ...         ...        ...
# 1659970     70001.0  South Sudan         2748         NaN       1388
# 1659971     70001.0  South Sudan         2748         NaN       1388
# 1662855     70001.0  South Sudan         2751         NaN       1386
# 1664521     70001.0  South Sudan         2754         NaN       1384
# 1664523     70001.0  South Sudan         2754         NaN       1384
#
#         Market_Name  Commodity_ID          Commodity_Name Currency_Name  \
# ...

# %%
mask=globe4['Commodity_ID']==465
globe4[mask]                                         # Wage(non qualified)
# Out:
#          Country_ID Country_Name  Locality_ID    Locality  Market_ID  \
# 735             1.0  Afghanistan          272  Badakhshan        266
# 737             1.0  Afghanistan          272  Badakhshan        266
# 747             1.0  Afghanistan          272  Badakhshan        266
# 757             1.0  Afghanistan          272  Badakhshan        266
# 758             1.0  Afghanistan          272  Badakhshan        266
# ...             ...          ...          ...         ...        ...
# 1857976       239.0   Tajikistan         2850         NaN        303
# 1869568       249.0       Turkey            0         NaN       1319
# 1869569       249.0       Turkey            0         NaN       1319
# 1869575       249.0       Turkey            0         NaN       1319
# 1869587       249.0       Turkey            0         NaN       1319
#
#               Market_Name  Commodity_ID  \
# 735              Fayzabad           465
# 737              Fayzabad           465
# ...

# %%
reset_data=globe4.drop(globe4.index[435:758])
reset_data                                          # Done with removing duplicates
# Out:
#          Country_ID Country_Name  Locality_ID    Locality  Market_ID  \
# 0              1.00  Afghanistan          272  Badakhshan        266
# 12             1.00  Afghanistan          272  Badakhshan        266
# 19             1.00  Afghanistan          272  Badakhshan        266
# 20             1.00  Afghanistan          272  Badakhshan        266
# 21             1.00  Afghanistan          272  Badakhshan        266
# ...             ...          ...          ...         ...        ...
# 2050633      271.00     Zimbabwe         3444    Midlands       5594
# 2050634      271.00     Zimbabwe         3444    Midlands       5594
# 2050635      271.00     Zimbabwe         3444    Midlands       5594
# 2050636      271.00     Zimbabwe         3444    Midlands       5594
# 2050637      271.00     Zimbabwe         3444    Midlands       5594
#
#         Market_Name  Commodity_ID           Commodity_Name Currency_Name  \
# ...

# %%
re_index=pd.Index(range(1,1433822))
transformed=reset_data.set_index(re_index)           # Re_indexing the dataset for ordering of row numbers
transformed
# Out:
#          Country_ID Country_Name  Locality_ID    Locality  Market_ID  \
# 1              1.00  Afghanistan          272  Badakhshan        266
# 2              1.00  Afghanistan          272  Badakhshan        266
# 3              1.00  Afghanistan          272  Badakhshan        266
# 4              1.00  Afghanistan          272  Badakhshan        266
# 5              1.00  Afghanistan          272  Badakhshan        266
# ...             ...          ...          ...         ...        ...
# 1433817      271.00     Zimbabwe         3444    Midlands       5594
# 1433818      271.00     Zimbabwe         3444    Midlands       5594
# 1433819      271.00     Zimbabwe         3444    Midlands       5594
# 1433820      271.00     Zimbabwe         3444    Midlands       5594
# 1433821      271.00     Zimbabwe         3444    Midlands       5594
#
#         Market_Name  Commodity_ID           Commodity_Name Currency_Name  \
# ...

# %%
# Setting the float dtype of Price to two decimal places and separating digits with commas where possible

pd.options.display.float_format='{:,.2f}'.format       # The dataset is now cleaned and rearranged
transformed
# Out:
#          Country_ID Country_Name  Locality_ID    Locality  Market_ID  \
# 1              1.00  Afghanistan          272  Badakhshan        266
# 2              1.00  Afghanistan          272  Badakhshan        266
# 3              1.00  Afghanistan          272  Badakhshan        266
# 4              1.00  Afghanistan          272  Badakhshan        266
# 5              1.00  Afghanistan          272  Badakhshan        266
# ...             ...          ...          ...         ...        ...
# 1433817      271.00     Zimbabwe         3444    Midlands       5594
# 1433818      271.00     Zimbabwe         3444    Midlands       5594
# 1433819      271.00     Zimbabwe         3444    Midlands       5594
# 1433820      271.00     Zimbabwe         3444    Midlands       5594
# 1433821      271.00     Zimbabwe         3444    Midlands       5594
#
#         Market_Name  Commodity_ID           Commodity_Name Currency_Name  \
# ...

# %%
verify=transformed.Country_Name
verify                                  # I want to get the total number of countires involved in the dataset
# Out:
# 1          Afghanistan
# 2          Afghanistan
# 3          Afghanistan
# 4          Afghanistan
# 5          Afghanistan
#               ...
# 1433817       Zimbabwe
# 1433818       Zimbabwe
# 1433819       Zimbabwe
# 1433820       Zimbabwe
# 1433821       Zimbabwe
# Name: Country_Name, Length: 1433821, dtype: object

# %%
verify.duplicated()
# Out:
# 1          False
# 2           True
# 3           True
# 4           True
# 5           True
#            ...
# 1433817     True
# 1433818     True
# 1433819     True
# 1433820     True
# 1433821     True
# Name: Country_Name, Length: 1433821, dtype: bool

# %%
verify[verify.duplicated()]
# Out:
# 2          Afghanistan
# 3          Afghanistan
# 4          Afghanistan
# 5          Afghanistan
# 6          Afghanistan
#               ...
# 1433817       Zimbabwe
# 1433818       Zimbabwe
# 1433819       Zimbabwe
# 1433820       Zimbabwe
# 1433821       Zimbabwe
# Name: Country_Name, Length: 1433723, dtype: object

# %%
verify.drop_duplicates()
# Out:
# 1          Afghanistan
# 8984           Algeria
# 9771            Angola
# 10909        Argentina
# 11799          Armenia
#               ...
# 1371648      Venezuela
# 1371654       Viet Nam
# 1371920          Yemen
# 1393428         Zambia
# 1425204       Zimbabwe
# Name: Country_Name, Length: 98, dtype: object

# %% [markdown]
# ## from here it's seen that the total number of countries involved is 98,
# ## ranging from Afghanistan down to Zimbabwe

# %%
transformed.groupby('Country_Name').sum().plot(kind='pie',y='Price')
# Out:
# <AxesSubplot:ylabel='Price'>

# %%
transformed.groupby('Country_Name').sum().plot(kind='bar',y='Price',color='green')
# Out:
# <AxesSubplot:xlabel='Country_Name'>

# %%
column=transformed['Price']
max_value=column.max()
max_value
# Out:
# 21777780.0

# %%
column=transformed['Price']
max_index=column.idxmax()
max_index
# Out:
# 300011

# %%
mask=transformed['Price'].values==21777780.0
check=transformed[mask]
check
# Out:
#         Country_ID Country_Name  Locality_ID   Locality  Market_ID  \
# 300011       57.00     Colombia          935  Antioquia        842
#
#        Market_Name  Commodity_ID            Commodity_Name Currency_Name  \
# 300011    Medellin           133  Rice (white) - Wholesale           COP
#
#        MarketType  Year         Price
# 300011  Wholesale  2016 21,777,780.00

# %% [markdown]
# # Colombia has the highest Price tag

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # For the sake of the large volume of this data, I would like to visualize at least two countries(Nigeria and Zimbabwe)

# %% [markdown]
# ## NIGERIA

# %%
mask=transformed['Country_Name'].values=='Nigeria'
new=transformed[mask]
new
# Out:
#         Country_ID Country_Name  Locality_ID Locality  Market_ID  \
# 888317      182.00      Nigeria         2211  Adamawa       1980
# 888318      182.00      Nigeria         2211  Adamawa       1980
# 888319      182.00      Nigeria         2211  Adamawa       1980
# 888320      182.00      Nigeria         2211  Adamawa       1980
# 888321      182.00      Nigeria         2211  Adamawa       1980
# ...            ...          ...          ...      ...        ...
# 925790      182.00      Nigeria        65710  Zamfara       1977
# 925791      182.00      Nigeria        65710  Zamfara       1977
# 925792      182.00      Nigeria        65710  Zamfara       1977
# 925793      182.00      Nigeria        65710  Zamfara       1977
# 925794      182.00      Nigeria        65710  Zamfara       1977
#
#          Market_Name  Commodity_ID                    Commodity_Name  \
# 888317          Mubi            55                    Bread - Retail
# ...

# %%
 # Using seaborn to visualize commodity name as against the corresponding given prices


sns.barplot(x='Commodity_Name',y='Price',data=new)           # For " Nigeria " 
plt.show()

# %%
column=new["Price"]
max_value=column.max()        # Nigeria has a maximum Price of NGN90000
max_value
# Out:
# 90000.0

# %%
column=new["Price"]
max_index=column.idxmax()     # The index bearing the maximum Price of NGN90000
max_index
# Out:
# 913534

# %%
mask=new['Price'].values==90000
newN=new[mask]                  # Viewing the entire rows having maximum Price
newN
# Out:
#         Country_ID Country_Name  Locality_ID Locality  Market_ID Market_Name  \
# 913534      182.00      Nigeria         2240     Yobe       1969    Damaturu
# 913541      182.00      Nigeria         2240     Yobe       1969    Damaturu
#
#         Commodity_ID   Commodity_Name Currency_Name MarketType  Year     Price
# 913534            99  Yam - Wholesale           NGN  Wholesale  2016 90,000.00
# 913541            99  Yam - Wholesale           NGN  Wholesale  2017 90,000.00

# %% [markdown]
# ## ZIMBABWE

# %%
mask=transformed['Country_Name'].values=='Zimbabwe'
new1=transformed[mask]
new1
# Out:
#          Country_ID Country_Name  Locality_ID  Locality  Market_ID  \
# 1425204      271.00     Zimbabwe         3435  Bulawayo        715
# 1425205      271.00     Zimbabwe         3435  Bulawayo        715
# 1425206      271.00     Zimbabwe         3435  Bulawayo        715
# 1425207      271.00     Zimbabwe         3435  Bulawayo        715
# 1425208      271.00     Zimbabwe         3435  Bulawayo        715
# ...             ...          ...          ...       ...        ...
# 1433817      271.00     Zimbabwe         3444  Midlands       5594
# 1433818      271.00     Zimbabwe         3444  Midlands       5594
# 1433819      271.00     Zimbabwe         3444  Midlands       5594
# 1433820      271.00     Zimbabwe         3444  Midlands       5594
# 1433821      271.00     Zimbabwe         3444  Midlands       5594
#
#                   Market_Name  Commodity_ID           Commodity_Name  \
# 1425204  Renkini Bus Terminus            50           Beans - Retail
# ...

# %%
 # Using seaborn to visualize commodity name as against the corresponding given prices
    
sns.barplot(x='Commodity_Name',y='Price',data=new1)         # For " Zimbabwe "
plt.show()

# %%
column=new1["Price"]
max_value=column.max()        # Zimbabwe has a maximum of ZWL4225
max_value
# Out:
# 4225.0

# %%
column=new1['Price']
max_index=column.idxmax()               # The index bearing the maximum Price of ZWL4225
max_index
# Out:
# 1425931

# %%
mask=new1['Price'].values==4225
new2=new1[mask]                    # The view of the particular row bearing both the index and the Price
new2
# Out:
#          Country_ID Country_Name  Locality_ID Locality  Market_ID Market_Name  \
# 1425931      271.00     Zimbabwe         3436   Harare       5451   Chadcombe
#
#          Commodity_ID           Commodity_Name Currency_Name MarketType  Year  \
# 1425931           887  Fish (kapenta) - Retail           ZWL     Retail  2021
#
#            Price
# 1425931 4,225.00
